# %% [markdown]
# # Not going to end up needing this, my EDA and such for Part 2 is in the data_exploring.ipynb file

# %%
import numpy as np
import pandas as pd
import json

# %%
df = pd.read_table('http://www.j-archive.com/showgame.php?game_id=5458', header=None)

# %%
df
# Out:
#                                                       0
# 0     <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//...
# 1     <html xmlns="http://www.w3.org/1999/xhtml" xml...
# 2                                                <head>
# 3     <title>J! Archive - Show #7402, aired 2016-11-...
# 4     <link type="text/css" rel="styleSheet" href="h...
# 5     <link rel="shortcut icon" href="http://www.j-a...
# 6                                               </head>
# 7                                                <body>
# 8                                     <div id="navbar">
# 9       <span id="navbarlogo"><a href="http://www.j-...
# 10      <span id="navbartext"><a href="http://www.j-...
# 11      <form id="navbarsearch" action="http://www.j...
# 12                          <fieldset class="noborder">
# 13          <input type="text" class="search" name="...
# 14          <input type="submit" class="search_butto...
# 15                                          </fieldset>
# ...

# %%
df[0][83]
# Out:
# '      <div onmouseover="toggle(\'clue_J_1_1\', \'clue_J_1_1_stuck\', \'&lt;em class=&quot;correct_response&quot;&gt;a pediatrician&lt;/em&gt;&lt;br /&gt;&lt;br /&gt;&lt;table width=&quot;100%&quot;&gt;&lt;tr&gt;&lt;td class=&quot;right&quot;&gt;Sharath&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;\')" onmouseout="toggle(\'clue_J_1_1\', \'clue_J_1_1_stuck\', \'This doctor specializes in children &amp; their diseases\')" onclick="togglestick(\'clue_J_1_1_stuck\')">'

# %%
df = pd.DataFrame(test)

# %%
df.head()
# Out:
#                     airdate     answer  \
# 0  2012-04-10T12:00:00.000Z  grenadine
#
#                                             category  category_id  \
# 0  {u'updated_at': u'2014-02-14T02:40:59.032Z', u...        15039
#
#                  created_at game_id      id invalid_count  \
# 0  2014-02-14T02:40:59.492Z    None  110806          None
#
#                                             question  \
# 0  Any cowboy knows a Roy Rogers requires me, thi...
#
#                  updated_at  value
# 0  2014-02-14T02:40:59.492Z    600

# %%
df['category'][0]
# Out:
# {'clues_count': 10,
#  'created_at': '2014-02-14T02:40:59.032Z',
#  'id': 15039,
#  'title': 'put me in',
#  'updated_at': '2014-02-14T02:40:59.032Z'}

# %%
df['question'][0]
# Out:
# 'Any cowboy knows a Roy Rogers requires me, this pomegranate-flavored syrup'

# %%
df2 = pd.read_csv('data/JEOPARDY_CSV.csv')

# %%
df2.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
pd.read_json('data/test.json')
# Out:
#                      airdate                                   answer  \
# 0   1985-02-08T12:00:00.000Z                             Election Day
# 1   1985-02-08T12:00:00.000Z                     the Western division
# 2   1985-02-08T12:00:00.000Z      sold flowers (flower girl accepted)
# 3   1985-02-08T12:00:00.000Z                     <i>Star Trek III</i>
# 4   1985-02-08T12:00:00.000Z                  (1 of) kangaroo and emu
# 5   1985-02-08T12:00:00.000Z                               cat people
# 6   1985-02-08T12:00:00.000Z                                    Maine
# 7   1985-02-08T12:00:00.000Z                                 a midget
# 8   1985-02-08T12:00:00.000Z                                wranglers
# 9   1985-02-08T12:00:00.000Z                    <i>Risky Business</i>
# 10  1985-02-08T12:00:00.000Z                       "Waltzing Matilda"
# 11  1985-02-08T12:00:00.000Z                               a catapult
# ...

# %%
df2 = pd.read_csv('data/adjusted-all-winnings.csv')

# %%
df2.head()
# Out:
#    Rk                                               Name  Total Adj  \
# 0 NaN  Brad Rutter<span style="display: none;">5+ old...  4,475,204
# 1 NaN  Ken Jennings<span style="display: none;">newva...  3,120,700
# 2 NaN  Jerome Vered<span style="display: none;">5+ ol...    638,403
# 3 NaN  Bob Verini<span style="display: none;">5+ oldv...    523,604
# 4 NaN  Roger Craig<span style="display: none;">newval...    530,200
#
#   First 5 Total Adj     Type  Wins Regular Adj First 5 Adj  TOC Adj  \
# 0         4,475,204  Regular   5.0     110,204     110,204  250,000
# 1           756,000  Regular  74.0   2,520,700     156,000      NaN
# 2           638,403  Regular   5.0     193,602     193,602   50,000
# 3           523,604  Regular   5.0      93,604      93,604  250,000
# 4           495,801  Regular   6.0     230,200     195,801  250,000
#
#        Other                                        TOC, finish
# 0  4,115,000  2001, winner<span style="display: none;">allTO...
# ...

# %%
df2['Name'][0]
# Out:
# 'Brad Rutter<span style="display: none;">5+ oldval</span>'

# %%
df2['TOC, finish'][0]
# Out:
# '2001, winner<span style="display: none;">allTOC SF+ finalist BOTD MDM UTOC</span>'
