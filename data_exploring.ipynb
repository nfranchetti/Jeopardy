# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/JEOPARDY_CSV.csv')
df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
df.columns
# Out:
# Index([u'Show Number', u' Air Date', u' Round', u' Category', u' Value',
#        u' Question', u' Answer'],
#       dtype='object')

# %%
# Remove the dumb spaces
df.columns = ['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question', 'Answer']

# %%
df.shape
# Out:
# (216930, 7)

# %%
df.dtypes
# Out:
# Show Number     int64
# Air Date       object
# Round          object
# Category       object
# Value          object
# Question       object
# Answer         object
# dtype: object

# %%
df['Air Date'] = pd.to_datetime(df['Air Date'])

# %%
df.sort_values('Air Date').head()
# Out:
#        Show Number   Air Date             Round            Category  Value  \
# 84523            1 1984-09-10         Jeopardy!      LAKES & RIVERS   $100
# 84565            1 1984-09-10  Double Jeopardy!           THE BIBLE  $1000
# 84566            1 1984-09-10  Double Jeopardy!            '50'S TV  $1000
# 84567            1 1984-09-10  Double Jeopardy!  NATIONAL LANDMARKS  $1000
# 84568            1 1984-09-10  Double Jeopardy!           NOTORIOUS  $1000
#
#                                                 Question             Answer
# 84523            River mentioned most often in the Bible         the Jordan
# 84565  According to 1st Timothy, it is the "root of a...  the love of money
# 84566  Name under which experimenter Don Herbert taug...         Mr. Wizard
# 84567    D.C. building shaken by November '83 bomb blast        the Capitol
# 84568  After the deed, he leaped to the stage shoutin...  John Wilkes Booth

# %%
df.sort_values('Air Date').tail()
# Out:
#         Show Number   Air Date      Round                 Category   Value  \
# 105947         6300 2012-01-27  Jeopardy!        VISITING THE CITY    $800
# 105948         6300 2012-01-27  Jeopardy!                    PANTS  $1,400
# 105949         6300 2012-01-27  Jeopardy!             CHILD ACTORS    $800
# 105951         6300 2012-01-27  Jeopardy!  LESSER-KNOWN SCIENTISTS    $800
# 105930         6300 2012-01-27  Jeopardy!                    PANTS    $200
#
#                                                  Question             Answer
# 105947  There's a great opera house on Bennelong Point...             Sydney
# 105948  Tight-fitting pants patterned after those worn...     toreador pants
# 105949  This kid, with a familiar last name, is seen <...        Jaden Smith
# 105951  Joseph Lagrange insisted on 10 as the basic un...  the metric system
# 105930  A synonym for freight, or pants with large bel...        cargo pants

# %%
df.isnull().any()
# Out:
# Show Number    False
# Air Date       False
# Round          False
# Category       False
# Value          False
# Question       False
# Answer         False
# dtype: bool

# %%
df[df['Value'] == 'None']
# Out:
#         Show Number   Air Date            Round  \
# 55             4680 2004-12-31  Final Jeopardy!
# 116            5957 2010-07-06  Final Jeopardy!
# 174            3751 2000-12-18  Final Jeopardy!
# 235            3673 2000-07-19  Final Jeopardy!
# 296            4931 2006-02-06  Final Jeopardy!
# 357            5690 2009-05-08  Final Jeopardy!
# 418            2825 1996-12-06  Final Jeopardy!
# 474            6037 2010-12-07  Final Jeopardy!
# 535            5243 2007-05-30  Final Jeopardy!
# 594            3036 1997-11-10  Final Jeopardy!
# 655            4107 2002-06-11  Final Jeopardy!
# 716            2735 1996-06-21  Final Jeopardy!
# 945                               THEATRE  None
# 1003                        FILM CLASSICS  None
# 1064                   NONFICTION AUTHORS  None
# 1125             KNOWLEDGE BY THE NUMBERS  None
# 1186                         FAMOUS NAMES  None
# 1247                     CABLE TELEVISION  None
# 1308                        THE 50 STATES  None
# 1369                                 ASIA  None
# 1426                      WORLD GEOGRAPHY  None
# 1487                   20th CENTURY BOOKS  None
# 1548             19th CENTURY POLITICIANS  None
# 1609               PRESIDENTIAL ELECTIONS  None
# 1670    INFLUENTIAL 19th CENTURY THINKERS  None
# 1731       HISTORIC PROPERTY TRANSACTIONS  None
# 1792                            MOUNTAINS  None
# ...                                   ...   ...
# 215201               20th CENTURY AUTHORS  None
# 215259                     WORLD BUSINESS  None
# 215319                INTERNATIONAL STARS  None
# 215380                           BROADWAY  None
# 215431                   MOVIE CHARACTERS  None
# 215488                        U.S. STATES  None
# 215548                      OSCAR WINNERS  None
# 215608                       MODERN MUSIC  None
# 215669        THE HISTORY OF CLIFFS NOTES  None
# 215729                    NAME'S THE SAME  None
# 215790                               WOOD  None
# 215851                   HISTORICAL TERMS  None
# 215912               COUNTRY DEMOGRAPHICS  None
# 215965                           RELIGION  None
# 216026                          GEOGRAPHY  None
# 216086                             PEOPLE  None
# 216147                    NAME'S THE SAME  None
# 216208                           MONARCHS  None
# 216264                            ROYALTY  None
# 216325             19th CENTURY INVENTORS  None
# 216384                         ON THE MAP  None
# 216445                          THE BIBLE  None
# 216506                            CASTLES  None
# 216567                    SHOPPING U.S.A.  None
# 216628                   GODS & GODDESSES  None
# 216686   MAJOR LEAGUE BASEBALL TEAM NAMES  None
# 216746                        SKYSCRAPERS  None
# 216807                  NATIONAL CAPITALS  None
# 216868                BESTSELLING AUTHORS  None
# 216929                     HISTORIC NAMES  None
#
#                                                  Question  \
# 55      Objects that pass closer to the sun than Mercu...
# 116     She was born in Virginia around 1596 & died in...
# 174     If Joe DiMaggio's hitting streak had gone one ...
# 235     Bordering Italy, Austria, Hungary & Croatia, i...
# 296     On December 27, 1831 it departed Plymouth, Eng...
# 357     He filed for divorce citing Leviticus 20:21, "...
# 418           This 1895 novel is subtitled "An Invention"
# 474     In use from 1844 to 1905, a flag representing ...
# 535     Richard Attenborough, who was in the original ...
# 594     Word completing the line "Nor shall any person...
# 655     This common term originated in the early 1500s...
# 716     On May 29, 1765 Patrick Henry's Stamp Act prot...
# 777     Owain Glyndwr, who died circa 1416, was the la...
# 836     Bill Harmsen, who raised horses in Colo., happ...
# 886     If a president is impeached, this official pre...
# 945     The 1996 musical "Play On!" gets its title fro...
# 1003    This 1951 classic stars the AFI's top picks fo...
# 1064    First published in 1946, a book written by thi...
# 1125    Number of males who served as British PM in th...
# 1186    He published a history of Virginia & New Engla...
# 1247    The name of this channel can be traced back to...
# 1308    Since 1776, it has been the only U.S. state to...
# 1369            It's Asia's southernmost national capital
# 1426    One story says this point was so named becuase...
# 1487    Chapter I of this book tells us: "Worse than t...
# 215669                                           \"1984\"
# 215729                                        Secretariat
# 215790                                        the longbow
# 215851              the French Revolution and World War I
# 215912                                              China
# 215965                                    Mary Baker Eddy
# 216026                                             Russia
# 216086       Fred Rogers (of Mister Rogers' Neighborhood)
# 216147                                            cricket
# 216208                                         Wilhelmina
# 216264                                        Charles III
# 216325                                       Alfred Nobel
# 216384                    (2 of) Turkey, Russia, or Egypt
# 216445                                                  8
# 216506                                    Balmoral Castle
# 216567                                           Wal-Mart
# 216628                                               Mars
# 216686                                 Pittsburgh Pirates
# 216746                                             Moscow
# 216807                                            Nicosia
# 216868                                       John Grisham
# 216929                     Grigori Alexandrovich Potemkin
#
# [3634 rows x 7 columns]

# %%
df['Value'] = df['Value'].str.replace('$','')
df['Value'] = df['Value'].str.replace(',','')
# df['Value'] = df['Value'].str.replace('None', np.nan)
# df['Value'].astype(int)
df.head()
# Out:
#    Show Number   Air Date      Round                         Category Value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY   200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE   200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
df['Value']
# Out:
# 0          200
# 1          200
# 2          200
# 3          200
# 4          200
# 5          200
# 6          400
# 7          400
# 8          400
# 9          400
# 10         400
# 11         400
# 12         600
# 13         600
# 14         600
# 15         600
# 16         600
# 17         600
# 18         800
# 19         800
# 20         800
# 21         800
# 22        2000
# 23         800
# 24        1000
# 25        1000
# 26        1000
# 27        1000
# 28        1000
# 29         400
#           ...
# 216900     400
# 216901     400
# 216902     400
# 216903     400
# 216904     400
# 216905     800
# 216906     800
# 216907     800
# 216908     800
# 216909     800
# 216910     800
# 216911    1200
# 216912    1200
# 216913    1200
# 216914    1200
# 216915    1200
# 216916    2200
# 216917    3400
# 216918    1600
# 216919    1600
# 216920    1600
# 216921    1600
# 216922    1600
# 216923    2000
# 216924    2000
# 216925    2000
# 216926    2000
# 216927    2000
# 216928    2000
# 216929    None
# Name: Value, dtype: object

# %%
df['Category'].value_counts()
# Out:
# BEFORE & AFTER                547
# SCIENCE                       519
# LITERATURE                    496
# AMERICAN HISTORY              418
# POTPOURRI                     401
# WORLD HISTORY                 377
# WORD ORIGINS                  371
# COLLEGES & UNIVERSITIES       351
# HISTORY                       349
# SPORTS                        342
# U.S. CITIES                   339
# WORLD GEOGRAPHY               338
# BODIES OF WATER               327
# ANIMALS                       324
# STATE CAPITALS                314
# BUSINESS & INDUSTRY           311
# ISLANDS                       301
# WORLD CAPITALS                300
# U.S. GEOGRAPHY                299
# RELIGION                      297
# SHAKESPEARE                   294
# Name for the group that picks the president, vice president & pope                                                 1
# The 1st prime minister of independent Kenya                                                                        1
# With 5 Olympic gold medals, she's the most successful U.S. women's speed skater in history                         1
# A state park in Burnet County, Texas appropriately bears the name of this breed of cattle                          1
# Set during the Vietnam War, it captured 5 Oscars including one for director Michael Cimino                         1
# In a recent autobiography, ex-wife Cyndy claims that she wrote college term papers for this ball player            1
# You wouldn't be wrong if you knew this comic said, "Curiosity killed the cat, but for a while I was a suspect"     1
# It was formerly the capital of East Bengal and East Pakistan                                                       1
# Rats have poor vision but can enhance their perception by using these, also called vibrissae                       1
# Christopher Atkins was marooned on an island with Brooke Shields in this, his first film                           1
# On TV, it's the brand of beer brewed by Drew Carey & his friends                                                   1
# It's the only major African river emptying into the Mediterranean Sea                                              1
# With over $3 billion in annual sales, this soft drink has 6% of the U.S. market                                    1
# This fleet-footed Chicago Bear was named outstanding back in the Pro Bowl 3 times: 1967, 1968 & 1970               1
# Saturn's second largest moon, it's named for the mother of the gods                                                1
# Ideally, this, the apparent boundary between the sky & the Earth, is at 90 degrees from the zenith                 1
# In an old nursery rhyme four and twenty of these birds are baked into a pie served to a king                       1
# May 14, 1948 is considered this country's day of independence                                                      1
# "All reactionaries are paper" these animals                                                                        1
# Tasty tidbit (6)                                                                                                   1
# Name: Question, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
spam = df['Category'].values.tolist()

# %%
cvec = CountVectorizer()
cvec.fit(spam)
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
blob = cvec.transform(spam)

# %%
words  = pd.DataFrame(cvec.transform(spam).todense(),
             columns=cvec.get_feature_names())

words.transpose().sort_values(0, ascending=False).head(10).transpose()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-49-274175d4536c> in <module>()
# ----> 1 words  = pd.DataFrame(cvec.transform(spam).todense(),
#       2              columns=cvec.get_feature_names())
#       3
#       4 words.transpose().sort_values(0, ascending=False).head(10).transpose()
#
# /home/nick/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in todense(self, order, out)
#     689             `numpy.matrix` object that shares the same memory.
#     690         """
# --> 691         return np.asmatrix(self.toarray(order=order, out=out))
#     692
#     693     def toarray(self, order=None, out=None):
#
# /home/nick/anaconda2/lib/python2.7/site-packages/scipy/sparse/compressed.pyc in toarray(self, order, out)
#     918     def toarray(self, order=None, out=None):
#     919         """See the docstring for `spmatrix.toarray`."""
# --> 920         return self.tocoo(copy=False).toarray(order=order, out=out)
#     921
#     922     ##############################################################
#
# /home/nick/anaconda2/lib/python2.7/site-packages/scipy/sparse/coo.pyc in toarray(self, order, out)
#     250     def toarray(self, order=None, out=None):
#     251         """See the docstring for `spmatrix.toarray`."""
# --> 252         B = self._process_toarray_args(order, out)
#     253         fortran = int(B.flags.f_contiguous)
#     254         if not fortran and not B.flags.c_contiguous:
#
# /home/nick/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in _process_toarray_args(self, order, out)
#    1007             return out
#    1008         else:
# -> 1009             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1010
#    1011     def __numpy_ufunc__(self, func, method, pos, inputs, **kwargs):
#
# MemoryError:
